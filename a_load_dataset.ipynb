# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from os import path

# %%
pm25 = pd.read_csv("./dataset/pollution_pm25.csv")
ozone = pd.read_csv("./dataset/pollution_ozone.csv")
f_fule = pd.read_csv("./dataset/fossil-fuel-consumption-by-fuel-type.csv")

# %%
pm25.head()
# Out:
#    Exposure Id     Type      Country ISO3   Region         Name  \
# 0        12391  country  Afghanistan  AFG  country  Afghanistan
# 1        12392  country  Afghanistan  AFG  country  Afghanistan
# 2        12393  country  Afghanistan  AFG  country  Afghanistan
# 3        12394  country  Afghanistan  AFG  country  Afghanistan
# 4        12395  country  Afghanistan  AFG  country  Afghanistan
#
#    Exposure Lower  Exposure Mean  Exposure Upper  Year Pollutant  \
# 0            21.0           49.3            92.9  1990      pm25
# 1            23.1           48.6            91.9  1995      pm25
# 2            26.5           51.6            92.7  2000      pm25
# 3            26.1           46.2            77.0  2005      pm25
# 4            32.5           51.8            77.9  2010      pm25
#
#   Pollutant Name Region Name  Units
# 0           PM25     Country  µg/m3
# 1           PM25     Country  µg/m3
# 2           PM25     Country  µg/m3
# 3           PM25     Country  µg/m3
# ...

# %%
ozone.loc[ozone["Country"]=="Afghanistan"]
# Out:
#     Exposure Id     Type      Country ISO3   Region         Name  \
# 0         12405  country  Afghanistan  AFG  country  Afghanistan
# 1         12406  country  Afghanistan  AFG  country  Afghanistan
# 2         12407  country  Afghanistan  AFG  country  Afghanistan
# 3         12408  country  Afghanistan  AFG  country  Afghanistan
# 4         12409  country  Afghanistan  AFG  country  Afghanistan
# 5         12410  country  Afghanistan  AFG  country  Afghanistan
# 6         12411  country  Afghanistan  AFG  country  Afghanistan
# 7         12412  country  Afghanistan  AFG  country  Afghanistan
# 8         12413  country  Afghanistan  AFG  country  Afghanistan
# 9         12414  country  Afghanistan  AFG  country  Afghanistan
# 10        12415  country  Afghanistan  AFG  country  Afghanistan
# 11        12416  country  Afghanistan  AFG  country  Afghanistan
# 12        12417  country  Afghanistan  AFG  country  Afghanistan
# ...

# %%
f_fule.head()
# Out:
#    Entity Code  Year  Coal Consumption - TWh  Oil Consumption - TWh  \
# 0  Africa  NaN  1965              323.496138             327.333164
# 1  Africa  NaN  1966              323.122193             358.132674
# 2  Africa  NaN  1967              330.291585             355.281459
# 3  Africa  NaN  1968              343.512911             374.852131
# 4  Africa  NaN  1969              346.642922             379.973086
#
#    Gas Consumption - TWh
# 0               9.543754
# 1              10.669916
# 2              10.545670
# 3              10.688970
# 4              12.492000

# %%
f_fule.Code.unique()
# Out:
# array([nan, 'DZA', 'ARG', 'AUS', 'AUT', 'AZE', 'BGD', 'BLR', 'BEL', 'BRA',
#        'BGR', 'CAN', 'CHL', 'CHN', 'COL', 'HRV', 'CYP', 'CZE', 'DNK',
#        'ECU', 'EGY', 'EST', 'FIN', 'FRA', 'DEU', 'GRC', 'HKG', 'HUN',
#        'ISL', 'IND', 'IDN', 'IRN', 'IRQ', 'IRL', 'ISR', 'ITA', 'JPN',
#        'KAZ', 'KWT', 'LVA', 'LTU', 'LUX', 'MYS', 'MEX', 'MAR', 'NLD',
#        'NZL', 'MKD', 'NOR', 'OMN', 'PAK', 'PER', 'PHL', 'POL', 'PRT',
#        'QAT', 'ROU', 'RUS', 'SAU', 'SGP', 'SVK', 'SVN', 'ZAF', 'KOR',
#        'ESP', 'LKA', 'SWE', 'CHE', 'TWN', 'THA', 'TTO', 'TUR', 'TKM',
#        'UKR', 'ARE', 'GBR', 'USA', 'UZB', 'VEN', 'VNM', 'OWID_WRL'],
#       dtype=object)

# %%
f_fule.Entity.unique()
# Out:
# array(['Africa', 'Algeria', 'Argentina', 'Asia Pacific', 'Australia',
#        'Austria', 'Azerbaijan', 'Bangladesh', 'Belarus', 'Belgium',
#        'Brazil', 'Bulgaria', 'CIS', 'Canada', 'Central America', 'Chile',
#        'China', 'Colombia', 'Croatia', 'Cyprus', 'Czechia', 'Denmark',
#        'Eastern Africa', 'Ecuador', 'Egypt', 'Estonia', 'Europe',
#        'European Union', 'Finland', 'France', 'Germany', 'Greece',
#        'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran',
#        'Iraq', 'Ireland', 'Israel', 'Italy', 'Japan', 'Kazakhstan',
#        'Kuwait', 'Latvia', 'Lithuania', 'Luxembourg', 'Malaysia',
#        'Mexico', 'Middle Africa', 'Middle East', 'Morocco', 'Netherlands',
#        'New Zealand', 'Non-OECD', 'North America', 'North Macedonia',
#        'Norway', 'OECD', 'Oman', 'Pakistan', 'Peru', 'Philippines',
#        'Poland', 'Portugal', 'Qatar', 'Romania', 'Russia', 'Saudi Arabia',
# ...
