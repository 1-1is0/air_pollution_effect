# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_fossil_fuel=pd.read_csv('fossil-fuel-consumption-by-fuel-type.csv')
df_fossil_fuel
# Out:
#       Entity      Code  Year  Coal Consumption - TWh  Oil Consumption - TWh  \
# 0     Africa       NaN  1965              323.496138             327.333164
# 1     Africa       NaN  1966              323.122193             358.132674
# 2     Africa       NaN  1967              330.291585             355.281459
# 3     Africa       NaN  1968              343.512911             374.852131
# 4     Africa       NaN  1969              346.642922             379.973086
# ...      ...       ...   ...                     ...                    ...
# 4998   World  OWID_WRL  2016            43501.654556           51908.105111
# 4999   World  OWID_WRL  2017            43721.381222           52640.103972
# 5000   World  OWID_WRL  2018            44238.975333           53146.716556
# 5001   World  OWID_WRL  2019            43788.651056           53302.646333
# 5002   World  OWID_WRL  2020            42062.408028           48259.271139
#
#       Gas Consumption - TWh
# ...

# %%
df_fossil_fuel=df_fossil_fuel[((df_fossil_fuel['Year'] >=2010) |
               (df_fossil_fuel['Year']==1990) |
               (df_fossil_fuel['Year']==1995) |
               (df_fossil_fuel['Year'] ==2000) |
              (df_fossil_fuel['Year'] ==2005)) &
                            (df_fossil_fuel['Year'] <2020)]
df_fossil_fuel
# Out:
#       Entity      Code  Year  Coal Consumption - TWh  Oil Consumption - TWh  \
# 25    Africa       NaN  1990              877.809861            1145.123741
# 30    Africa       NaN  1995              921.802840            1264.970824
# 35    Africa       NaN  2000              963.273915            1421.515377
# 40    Africa       NaN  2005             1038.031248            1650.403414
# 45    Africa       NaN  2010             1162.992136            1966.073787
# ...      ...       ...   ...                     ...                    ...
# 4997   World  OWID_WRL  2015            44065.355083           51008.097861
# 4998   World  OWID_WRL  2016            43501.654556           51908.105111
# 4999   World  OWID_WRL  2017            43721.381222           52640.103972
# 5000   World  OWID_WRL  2018            44238.975333           53146.716556
# 5001   World  OWID_WRL  2019            43788.651056           53302.646333
#
#       Gas Consumption - TWh
# ...

# %%
list=set(df_fossil_fuel['Entity'])

# %%
df_ozon=pd.read_csv('pollution_ozone.csv')
df_ozon
# Out:
#       Exposure Id     Type      Country ISO3   Region         Name  \
# 0           12405  country  Afghanistan  AFG  country  Afghanistan
# 1           12406  country  Afghanistan  AFG  country  Afghanistan
# 2           12407  country  Afghanistan  AFG  country  Afghanistan
# 3           12408  country  Afghanistan  AFG  country  Afghanistan
# 4           12409  country  Afghanistan  AFG  country  Afghanistan
# ...           ...      ...          ...  ...      ...          ...
# 2851        13590  country     Zimbabwe  ZWE  country     Zimbabwe
# 2852        13591  country     Zimbabwe  ZWE  country     Zimbabwe
# 2853        13592  country     Zimbabwe  ZWE  country     Zimbabwe
# 2854        13593  country     Zimbabwe  ZWE  country     Zimbabwe
# 2855        13594  country     Zimbabwe  ZWE  country     Zimbabwe
#
#       Exposure Lower  Exposure Mean  Exposure Upper  Year Pollutant  \
# 0               55.7           56.6            57.5  1990     ozone
# ...

# %%
df_ozon.Country=df_ozon['Country'].str.replace("United States of America","United States",regex=False)
df_ozon.Country=df_ozon['Country'].str.replace("Democratic People's Republic of Korea","North Korea",regex=False)
df_ozon.Country=df_ozon['Country'].str.replace("Iran (Islamic Republic of)","Iran",regex=False)
df_ozon.Country=df_ozon['Country'].str.replace("Republic of Korea","South Korea",regex=False)
df_ozon.Country=df_ozon['Country'].str.replace("Russian Federation","Russia",regex=False)
df_ozon.Country=df_ozon['Country'].str.replace("Taiwan (Province of China)","Taiwan",regex=False)
df_ozon.Country=df_ozon['Country'].str.replace("Venezuela (Bolivarian Republic of)","Venezuela",regex=False)
df_ozon.Country=df_ozon['Country'].str.replace("Viet Nam","Vietnam",regex=False)

# %%
df_ozon=df_ozon.loc[df_ozon['Country'].isin(list)]
df_ozon
# Out:
#       Exposure Id     Type  Country ISO3   Region      Name  Exposure Lower  \
# 28          11649  country  Algeria  DZA  country   Algeria            49.4
# 29          11650  country  Algeria  DZA  country   Algeria            51.0
# 30          11651  country  Algeria  DZA  country   Algeria            54.3
# 31          11652  country  Algeria  DZA  country   Algeria            49.1
# 32          11653  country  Algeria  DZA  country   Algeria            51.5
# ...           ...      ...      ...  ...      ...       ...             ...
# 2809         7920  country  Vietnam  VNM  country  Viet Nam            38.5
# 2810         7921  country  Vietnam  VNM  country  Viet Nam            37.8
# 2811         7922  country  Vietnam  VNM  country  Viet Nam            37.8
# 2812         7923  country  Vietnam  VNM  country  Viet Nam            37.9
# 2813         7924  country  Vietnam  VNM  country  Viet Nam            37.7
#
# ...

# %%
df_pm25=pd.read_csv('pollution_pm25.csv')
df_pm25
# Out:
#       Exposure Id     Type      Country ISO3   Region         Name  \
# 0           12391  country  Afghanistan  AFG  country  Afghanistan
# 1           12392  country  Afghanistan  AFG  country  Afghanistan
# 2           12393  country  Afghanistan  AFG  country  Afghanistan
# 3           12394  country  Afghanistan  AFG  country  Afghanistan
# 4           12395  country  Afghanistan  AFG  country  Afghanistan
# ...           ...      ...          ...  ...      ...          ...
# 2851        13576  country     Zimbabwe  ZWE  country     Zimbabwe
# 2852        13577  country     Zimbabwe  ZWE  country     Zimbabwe
# 2853        13578  country     Zimbabwe  ZWE  country     Zimbabwe
# 2854        13579  country     Zimbabwe  ZWE  country     Zimbabwe
# 2855        13580  country     Zimbabwe  ZWE  country     Zimbabwe
#
#       Exposure Lower  Exposure Mean  Exposure Upper  Year Pollutant  \
# 0               21.0           49.3            92.9  1990      pm25
# ...

# %%
df_pm25.Country=df_pm25['Country'].str.replace("United States of America","United States",regex=False)
df_pm25.Country=df_pm25['Country'].str.replace("Democratic People's Republic of Korea","North Korea",regex=False)
df_pm25.Country=df_pm25['Country'].str.replace("Iran (Islamic Republic of)","Iran",regex=False)
df_pm25.Country=df_pm25['Country'].str.replace("Republic of Korea","South Korea",regex=False)
df_pm25.Country=df_pm25['Country'].str.replace("Russian Federation","Russia",regex=False)
df_pm25.Country=df_pm25['Country'].str.replace("Taiwan (Province of China)","Taiwan",regex=False)
df_pm25.Country=df_pm25['Country'].str.replace("Venezuela (Bolivarian Republic of)","Venezuela",regex=False)
df_pm25.Country=df_pm25['Country'].str.replace("Viet Nam","Vietnam",regex=False)

# %%
df_pm25=df_pm25.loc[df_pm25['Country'].isin(list)]
df_pm25
# Out:
#       Exposure Id     Type  Country ISO3   Region      Name  Exposure Lower  \
# 28          11635  country  Algeria  DZA  country   Algeria            21.2
# 29          11636  country  Algeria  DZA  country   Algeria            22.4
# 30          11637  country  Algeria  DZA  country   Algeria            24.1
# 31          11638  country  Algeria  DZA  country   Algeria            23.3
# 32          11639  country  Algeria  DZA  country   Algeria            22.6
# ...           ...      ...      ...  ...      ...       ...             ...
# 2809         7906  country  Vietnam  VNM  country  Viet Nam            18.1
# 2810         7907  country  Vietnam  VNM  country  Viet Nam            18.8
# 2811         7908  country  Vietnam  VNM  country  Viet Nam            16.7
# 2812         7909  country  Vietnam  VNM  country  Viet Nam            16.7
# 2813         7910  country  Vietnam  VNM  country  Viet Nam            16.6
#
# ...

# %%
df_solid_fuel=pd.read_csv('pollution_solid_fuels.csv')
df_solid_fuel
# Out:
#       Exposure Id     Type      Country ISO3   Region         Name  \
# 0           12419  country  Afghanistan  AFG  country  Afghanistan
# 1           12420  country  Afghanistan  AFG  country  Afghanistan
# 2           12421  country  Afghanistan  AFG  country  Afghanistan
# 3           12422  country  Afghanistan  AFG  country  Afghanistan
# 4           12423  country  Afghanistan  AFG  country  Afghanistan
# ...           ...      ...          ...  ...      ...          ...
# 2851        13604  country     Zimbabwe  ZWE  country     Zimbabwe
# 2852        13605  country     Zimbabwe  ZWE  country     Zimbabwe
# 2853        13606  country     Zimbabwe  ZWE  country     Zimbabwe
# 2854        13607  country     Zimbabwe  ZWE  country     Zimbabwe
# 2855        13608  country     Zimbabwe  ZWE  country     Zimbabwe
#
#       Exposure Lower  Exposure Mean  Exposure Upper  Year Pollutant  \
# 0              0.870          0.916           0.950  1990       hap
# ...

# %%
df_solid_fuel.Country=df_solid_fuel['Country'].str.replace("United States of America","United States",regex=False)
df_solid_fuel.Country=df_solid_fuel['Country'].str.replace("Democratic People's Republic of Korea","North Korea",regex=False)
df_solid_fuel.Country=df_solid_fuel['Country'].str.replace("Iran (Islamic Republic of)","Iran",regex=False)
df_solid_fuel.Country=df_solid_fuel['Country'].str.replace("Republic of Korea","South Korea",regex=False)
df_solid_fuel.Country=df_solid_fuel['Country'].str.replace("Russian Federation","Russia",regex=False)
df_solid_fuel.Country=df_solid_fuel['Country'].str.replace("Taiwan (Province of China)","Taiwan",regex=False)
df_solid_fuel.Country=df_solid_fuel['Country'].str.replace("Venezuela (Bolivarian Republic of)","Venezuela",regex=False)
df_solid_fuel.Country=df_solid_fuel['Country'].str.replace("Viet Nam","Vietnam",regex=False)

# %%
df_solid_fuel=df_solid_fuel.loc[df_solid_fuel['Country'].isin(list)]
df_solid_fuel
# Out:
#       Exposure Id     Type  Country ISO3   Region      Name  Exposure Lower  \
# 28          11663  country  Algeria  DZA  country   Algeria         0.03350
# 29          11664  country  Algeria  DZA  country   Algeria         0.02420
# 30          11665  country  Algeria  DZA  country   Algeria         0.01780
# 31          11666  country  Algeria  DZA  country   Algeria         0.01200
# 32          11667  country  Algeria  DZA  country   Algeria         0.00578
# ...           ...      ...      ...  ...      ...       ...             ...
# 2809         7934  country  Vietnam  VNM  country  Viet Nam         0.36500
# 2810         7935  country  Vietnam  VNM  country  Viet Nam         0.35000
# 2811         7936  country  Vietnam  VNM  country  Viet Nam         0.33500
# 2812         7937  country  Vietnam  VNM  country  Viet Nam         0.31900
# 2813         7938  country  Vietnam  VNM  country  Viet Nam         0.30500
#
# ...

# %%
list1=set(df_solid_fuel['Country'])

# %%
df_fossil_fuel=df_fossil_fuel.loc[df_fossil_fuel['Entity'].isin(list1)]

# %%
df1=df_fossil_fuel.rename(columns={'Entity':'Country'})
df1
# Out:
#       Country Code  Year  Coal Consumption - TWh  Oil Consumption - TWh  \
# 81    Algeria  DZA  1990                7.664170             111.811616
# 86    Algeria  DZA  1995                7.210600             103.142283
# 91    Algeria  DZA  2000                5.640550             103.132480
# 96    Algeria  DZA  2005                6.908220             134.213385
# 101   Algeria  DZA  2010                3.605300             181.611916
# ...       ...  ...   ...                     ...                    ...
# 4885  Vietnam  VNM  2015              305.123387             241.684151
# 4886  Vietnam  VNM  2016              330.179364             258.548071
# 4887  Vietnam  VNM  2017              329.915188             270.643767
# 4888  Vietnam  VNM  2018              439.513982             288.082323
# 4889  Vietnam  VNM  2019              574.244154             306.655864
#
#       Gas Consumption - TWh
# 81               195.098750
# 86               202.221250
# ...

# %%
df1 = pd.merge(df1, df_solid_fuel, on=['Country', 'Year'], how='left')

# %%
df1
# Out:
#       Country Code  Year  Coal Consumption - TWh  Oil Consumption - TWh  \
# 0     Algeria  DZA  1990                7.664170             111.811616
# 1     Algeria  DZA  1995                7.210600             103.142283
# 2     Algeria  DZA  2000                5.640550             103.132480
# 3     Algeria  DZA  2005                6.908220             134.213385
# 4     Algeria  DZA  2010                3.605300             181.611916
# ...       ...  ...   ...                     ...                    ...
# 1087  Vietnam  VNM  2015              305.123387             241.684151
# 1088  Vietnam  VNM  2016              330.179364             258.548071
# 1089  Vietnam  VNM  2017              329.915188             270.643767
# 1090  Vietnam  VNM  2018              439.513982             288.082323
# 1091  Vietnam  VNM  2019              574.244154             306.655864
#
#       Gas Consumption - TWh  Exposure Id     Type ISO3   Region      Name  \
# ...

# %%
pollution_HAT_coal = df1[["Country", "Code","Year","Coal Consumption - TWh","Exposure Mean"]]
pollution_HAT_coal
# Out:
#       Country Code  Year  Coal Consumption - TWh  Exposure Mean
# 0     Algeria  DZA  1990                7.664170        0.05860
# 1     Algeria  DZA  1995                7.210600        0.03930
# 2     Algeria  DZA  2000                5.640550        0.02500
# 3     Algeria  DZA  2005                6.908220        0.01460
# 4     Algeria  DZA  2010                3.605300        0.00717
# ...       ...  ...   ...                     ...            ...
# 1087  Vietnam  VNM  2015              305.123387        0.45700
# 1088  Vietnam  VNM  2016              330.179364        0.44400
# 1089  Vietnam  VNM  2017              329.915188        0.43200
# 1090  Vietnam  VNM  2018              439.513982        0.42000
# 1091  Vietnam  VNM  2019              574.244154        0.40800
#
# [1092 rows x 5 columns]

# %%
pollution_HAT_oil = df1[["Country", "Code","Year","Oil Consumption - TWh","Exposure Mean"]]
pollution_HAT_oil
# Out:
#       Country Code  Year  Oil Consumption - TWh  Exposure Mean
# 0     Algeria  DZA  1990             111.811616        0.05860
# 1     Algeria  DZA  1995             103.142283        0.03930
# 2     Algeria  DZA  2000             103.132480        0.02500
# 3     Algeria  DZA  2005             134.213385        0.01460
# 4     Algeria  DZA  2010             181.611916        0.00717
# ...       ...  ...   ...                    ...            ...
# 1087  Vietnam  VNM  2015             241.684151        0.45700
# 1088  Vietnam  VNM  2016             258.548071        0.44400
# 1089  Vietnam  VNM  2017             270.643767        0.43200
# 1090  Vietnam  VNM  2018             288.082323        0.42000
# 1091  Vietnam  VNM  2019             306.655864        0.40800
#
# [1092 rows x 5 columns]

# %%
pollution_HAT_gas = df1[["Country", "Code","Year","Gas Consumption - TWh","Exposure Mean"]]
pollution_HAT_gas
# Out:
#       Country Code  Year  Gas Consumption - TWh  Exposure Mean
# 0     Algeria  DZA  1990             195.098750        0.05860
# 1     Algeria  DZA  1995             202.221250        0.03930
# 2     Algeria  DZA  2000             191.012937        0.02500
# 3     Algeria  DZA  2005             223.559875        0.01460
# 4     Algeria  DZA  2010             253.272250        0.00717
# ...       ...  ...   ...                    ...            ...
# 1087  Vietnam  VNM  2015             102.869000        0.45700
# 1088  Vietnam  VNM  2016             102.386500        0.44400
# 1089  Vietnam  VNM  2017              95.206900        0.43200
# 1090  Vietnam  VNM  2018              96.596500        0.42000
# 1091  Vietnam  VNM  2019              98.526500        0.40800
#
# [1092 rows x 5 columns]

# %% [markdown]
# <div dir="rtl" lang="fa" style="color:purple;font">جداسازی کشورها بر اساس قاره</div>

# %%
africa=[  'Algeria', 'Egypt' ,'South Africa']
north_amrica= ['Canada' ,'United States']
south_amrica= ['Argentina','Brazil','Chile', 'Colombia' ,'Ecuador' ,'Mexico','Peru', 'Morocco','Trinidad and Tobago','Venezuela']
asia= ['Azerbaijan','Bangladesh' ,'Belarus', 'Bulgaria', 'China', 'India','Oman','Philippines', 'Pakistan', 'Qatar',
'Indonesia','Iran','Japan','Uzbekistan', 'Vietnam', 'Kazakhstan','Kuwait','Malaysia','Iraq','Israel','Russia',
 'Taiwan','Thailand','United Arab Emirates','Saudi Arabia','South Korea','Singapore','Sri Lanka']
europe= ['Austria','Belgium','Croatia','Cyprus', 'Ireland','Czechia','Italy','Denmark','Netherlands','Estonia','North Macedonia',
 'Finland','Norway','France','Poland','Portugal','Romania', 'Germany','Slovakia','Slovenia','Spain','Greece','Sweden','Switzerland',
 'Hungary','Ukraine','Iceland','Latvia','Lithuania','Turkey','Luxembourg','United Kingdom']
Oceania=['New Zealand','Australia']

# %%
pollution_HAT_coal_asia=pollution_HAT_coal.loc[pollution_HAT_coal['Country'].isin(asia)]

# %%
pollution_HAT_coal_asia.sum()
# Out:
# Country                   AzerbaijanAzerbaijanAzerbaijanAzerbaijanAzerba...
# Code                      AZEAZEAZEAZEAZEAZEAZEAZEAZEAZEAZEAZEAZEAZEBGDB...
# Year                                                                 787780
# Coal Consumption - TWh                                        389022.271248
# Exposure Mean                                                     90.333107
# dtype: object

# %%
pollution_HAT_oil_asia=pollution_HAT_oil.loc[pollution_HAT_oil['Country'].isin(asia)]

# %%
pollution_HAT_oil_asia.sum()
# Out:
# Country                  AzerbaijanAzerbaijanAzerbaijanAzerbaijanAzerba...
# Code                     AZEAZEAZEAZEAZEAZEAZEAZEAZEAZEAZEAZEAZEAZEBGDB...
# Year                                                                787780
# Oil Consumption - TWh                                        290813.268258
# Exposure Mean                                                    90.333107
# dtype: object

# %%
pollution_HAT_gas_asia=pollution_HAT_gas.loc[pollution_HAT_gas['Country'].isin(asia)]

# %%
pollution_HAT_gas_asia.sum()
# Out:
# Country                  AzerbaijanAzerbaijanAzerbaijanAzerbaijanAzerba...
# Code                     AZEAZEAZEAZEAZEAZEAZEAZEAZEAZEAZEAZEAZEAZEBGDB...
# Year                                                                787780
# Gas Consumption - TWh                                           196940.903
# Exposure Mean                                                    90.333107
# dtype: object

# %%
pollution_HAT_coal_africa=pollution_HAT_coal.loc[pollution_HAT_coal['Country'].isin(africa)]

# %%
pollution_HAT_coal_africa.sum()
# Out:
# Country                   AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Code                      DZADZADZADZADZADZADZADZADZADZADZADZADZADZAEGYE...
# Year                                                                  84405
# Coal Consumption - TWh                                         13892.668475
# Exposure Mean                                                       3.38664
# dtype: object

# %%
pollution_HAT_oil_africa=pollution_HAT_oil.loc[pollution_HAT_oil['Country'].isin(africa)]

# %%
pollution_HAT_oil_africa.sum()
# Out:
# Country                  AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Code                     DZADZADZADZADZADZADZADZADZADZADZADZADZADZAEGYE...
# Year                                                                 84405
# Oil Consumption - TWh                                         12385.016539
# Exposure Mean                                                      3.38664
# dtype: object

# %%
pollution_HAT_gas_africa=pollution_HAT_gas.loc[pollution_HAT_gas['Country'].isin(africa)]

# %%
pollution_HAT_gas_africa.sum()
# Out:
# Country                  AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Code                     DZADZADZADZADZADZADZADZADZADZADZADZADZADZAEGYE...
# Year                                                                 84405
# Gas Consumption - TWh                                         10624.825338
# Exposure Mean                                                      3.38664
# dtype: object

# %%
pollution_HAT_coal_north_amrica=pollution_HAT_coal.loc[pollution_HAT_coal['Country'].isin(north_amrica)]

# %%
pollution_HAT_coal_north_amrica.sum()
# Out:
# Country                   CanadaCanadaCanadaCanadaCanadaCanadaCanadaCana...
# Code                      CANCANCANCANCANCANCANCANCANCANCANCANCANCANUSAU...
# Year                                                                  56270
# Coal Consumption - TWh                                         72296.795417
# Exposure Mean                                                       0.08038
# dtype: object

# %%
pollution_HAT_oil_north_amrica=pollution_HAT_oil.loc[pollution_HAT_oil['Country'].isin(north_amrica)]

# %%
pollution_HAT_oil_north_amrica.sum()
# Out:
# Country                  CanadaCanadaCanadaCanadaCanadaCanadaCanadaCana...
# Code                     CANCANCANCANCANCANCANCANCANCANCANCANCANCANUSAU...
# Year                                                                 56270
# Oil Consumption - TWh                                        156976.605592
# Exposure Mean                                                      0.08038
# dtype: object

# %%
pollution_HAT_gas_north_amrica=pollution_HAT_gas.loc[pollution_HAT_gas['Country'].isin(north_amrica)]

# %%
pollution_HAT_gas_north_amrica.sum()
# Out:
# Country                  CanadaCanadaCanadaCanadaCanadaCanadaCanadaCana...
# Code                     CANCANCANCANCANCANCANCANCANCANCANCANCANCANUSAU...
# Year                                                                 56270
# Gas Consumption - TWh                                         110553.85703
# Exposure Mean                                                      0.08038
# dtype: object

# %%
pollution_HAT_coal_south_amrica=pollution_HAT_coal.loc[pollution_HAT_coal['Country'].isin(south_amrica)]

# %%
pollution_HAT_coal_south_amrica.sum()
# Out:
# Country                   ArgentinaArgentinaArgentinaArgentinaArgentinaA...
# Code                      ARGARGARGARGARGARGARGARGARGARGARGARGARGARGBRAB...
# Year                                                                 281350
# Coal Consumption - TWh                                          6776.409781
# Exposure Mean                                                      15.71985
# dtype: object

# %%
pollution_HAT_oil_south_amrica=pollution_HAT_oil.loc[pollution_HAT_oil['Country'].isin(south_amrica)]

# %%
pollution_HAT_oil_south_amrica.sum()
# Out:
# Country                  ArgentinaArgentinaArgentinaArgentinaArgentinaA...
# Code                     ARGARGARGARGARGARGARGARGARGARGARGARGARGARGBRAB...
# Year                                                                281350
# Oil Consumption - TWh                                         51244.733392
# Exposure Mean                                                     15.71985
# dtype: object

# %%
pollution_HAT_gas_south_amrica=pollution_HAT_gas.loc[pollution_HAT_gas['Country'].isin(south_amrica)]

# %%
pollution_HAT_gas_south_amrica.sum()
# Out:
# Country                  ArgentinaArgentinaArgentinaArgentinaArgentinaA...
# Code                     ARGARGARGARGARGARGARGARGARGARGARGARGARGARGBRAB...
# Year                                                                281350
# Gas Consumption - TWh                                         28967.576004
# Exposure Mean                                                     15.71985
# dtype: object

# %%
pollution_HAT_coal_europe=pollution_HAT_coal.loc[pollution_HAT_coal['Country'].isin(europe)]

# %%
pollution_HAT_coal_europe.sum()
# Out:
# Country                   AustriaAustriaAustriaAustriaAustriaAustriaAust...
# Code                      AUTAUTAUTAUTAUTAUTAUTAUTAUTAUTAUTAUTAUTAUTBELB...
# Year                                                                 900320
# Coal Consumption - TWh                                         57493.575001
# Exposure Mean                                                      23.14198
# dtype: object

# %%
pollution_HAT_oil_europe=pollution_HAT_oil.loc[pollution_HAT_oil['Country'].isin(europe)]

# %%
pollution_HAT_oil_europe.sum()
# Out:
# Country                  AustriaAustriaAustriaAustriaAustriaAustriaAust...
# Code                     AUTAUTAUTAUTAUTAUTAUTAUTAUTAUTAUTAUTAUTAUTBELB...
# Year                                                                900320
# Oil Consumption - TWh                                        117583.195196
# Exposure Mean                                                     23.14198
# dtype: object

# %%
pollution_HAT_gas_europe=pollution_HAT_gas.loc[pollution_HAT_gas['Country'].isin(europe)]

# %%
pollution_HAT_gas_europe.sum()
# Out:
# Country                  AustriaAustriaAustriaAustriaAustriaAustriaAust...
# Code                     AUTAUTAUTAUTAUTAUTAUTAUTAUTAUTAUTAUTAUTAUTBELB...
# Year                                                                900320
# Gas Consumption - TWh                                          75640.16911
# Exposure Mean                                                     23.14198
# dtype: object

# %%
pollution_HAT_coal_Oceania=pollution_HAT_coal.loc[pollution_HAT_coal['Country'].isin(Oceania)]
pollution_HAT_coal_Oceania.sum()
# Out:
# Country                   AustraliaAustraliaAustraliaAustraliaAustraliaA...
# Code                      AUSAUSAUSAUSAUSAUSAUSAUSAUSAUSAUSAUSAUSAUSNZLN...
# Year                                                                  56270
# Coal Consumption - TWh                                          7790.191767
# Exposure Mean                                                       0.18505
# dtype: object

# %%
pollution_HAT_oil_Oceania=pollution_HAT_oil.loc[pollution_HAT_oil['Country'].isin(Oceania)]
pollution_HAT_oil_Oceania.sum()
# Out:
# Country                  AustraliaAustraliaAustraliaAustraliaAustraliaA...
# Code                     AUSAUSAUSAUSAUSAUSAUSAUSAUSAUSAUSAUSAUSAUSNZLN...
# Year                                                                 56270
# Oil Consumption - TWh                                            8466.5671
# Exposure Mean                                                      0.18505
# dtype: object

# %%
pollution_HAT_gas_Oceania=pollution_HAT_gas.loc[pollution_HAT_gas['Country'].isin(Oceania)]
pollution_HAT_gas_Oceania.sum()
# Out:
# Country                  AustraliaAustraliaAustraliaAustraliaAustraliaA...
# Code                     AUSAUSAUSAUSAUSAUSAUSAUSAUSAUSAUSAUSAUSAUSNZLN...
# Year                                                                 56270
# Gas Consumption - TWh                                          5063.449628
# Exposure Mean                                                      0.18505
# dtype: object

# %%
pollution_HAT_coal_continent=pd.DataFrame({'continent':['Asia','North America','Europe','Africa','South America', 'Oceania','Australia' , 'Antarctica'],
                                          'Coal Consumption - TWh':[389022.271248, 72296.795417,57493.575001,13892.668475,6776.409781,7790.191767,0,0],
                                          'Exposure Mean':[90.333107, 0.08038,23.14198,3.38664,15.71985, 0.18505,0, 0]})

# %%
pollution_HAT_coal_continent
# Out:
#        continent  Coal Consumption - TWh  Exposure Mean
# 0           Asia           389022.271248      90.333107
# 1  North America            72296.795417       0.080380
# 2         Europe            57493.575001      23.141980
# 3         Africa            13892.668475       3.386640
# 4  South America             6776.409781      15.719850
# 5        Oceania             7790.191767       0.185050
# 6      Australia                0.000000       0.000000
# 7     Antarctica                0.000000       0.000000

# %%
pollution_HAT_oil_continent=pd.DataFrame({'continent':['Asia','North America','Europe','Africa','South America', 'Oceania','Australia' , 'Antarctica'],
                                         'Oil Consumption - TWh' :[290813.268258, 156976.605592, 117583.195196,12385.016539,  51244.733392,8466.5671,0,0],
                                         'Exposure Mean':[90.333107, 0.08038,23.14198,3.38664,15.71985, 0.18505,0, 0]})
pollution_HAT_oil_continent
# Out:
#        continent  Oil Consumption - TWh  Exposure Mean
# 0           Asia          290813.268258      90.333107
# 1  North America          156976.605592       0.080380
# 2         Europe          117583.195196      23.141980
# 3         Africa           12385.016539       3.386640
# 4  South America           51244.733392      15.719850
# 5        Oceania            8466.567100       0.185050
# 6      Australia               0.000000       0.000000
# 7     Antarctica               0.000000       0.000000

# %%
pollution_HAT_gas_continent=pd.DataFrame({'continent':['Asia', 'North America', 'Europe', 'Africa', 'South America', 'Oceania','Australia', 'Antarctica'],
                                         'Gas Consumption - TWh' :[196940.903,110553.85703,75640.16911, 10624.825338, 28967.576004, 5063.449628,0, 0],
                                         'Exposure Mean':[90.333107, 0.08038,23.14198,3.38664,15.71985, 0.18505,0, 0]})
pollution_HAT_gas_continent
# Out:
#        continent  Gas Consumption - TWh  Exposure Mean
# 0           Asia          196940.903000      90.333107
# 1  North America          110553.857030       0.080380
# 2         Europe           75640.169110      23.141980
# 3         Africa           10624.825338       3.386640
# 4  South America           28967.576004      15.719850
# 5        Oceania            5063.449628       0.185050
# 6      Australia               0.000000       0.000000
# 7     Antarctica               0.000000       0.000000

# %%
fig, ax = plt.subplots()

colors = {'North_America':'red','South_America':'purple', 'Europe':'green', 'Asia':'blue', 'Africa':'yellow','Oceania':'pink','Antarctica':'gray'}

grouped = pollution_HAT_coal_continent.groupby('continent')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='Coal Consumption - TWh', y='Exposure Mean', label=key, color=colors[key])

plt.show()

# %%
import requests
import geopandas as gpd

# %%
cont = requests.get(
    "https://gist.githubusercontent.com/hrbrmstr/91ea5cc9474286c72838/raw/59421ff9b268ff0929b051ddafafbeb94a4c1910/continents.json"
)

# %%
gdf = gpd.GeoDataFrame.from_features(cont.json())

gdf = gdf.assign(
    total_pageviews=np.random.randint(10 ** 7, 10 ** 9, len(gdf))
).set_index("CONTINENT")
gdf
# Out:
#                                                         geometry  \
# CONTINENT
# Asia           MULTIPOLYGON (((93.27554 80.26361, 93.14804 80...
# North America  MULTIPOLYGON (((-25.28167 71.39166, -25.62389 ...
# Europe         MULTIPOLYGON (((58.06138 81.68776, 57.88986 81...
# Africa         MULTIPOLYGON (((0.69465 5.77337, 0.63583 5.944...
# South America  MULTIPOLYGON (((-81.71306 12.49028, -81.72015 ...
# Oceania        MULTIPOLYGON (((-177.39334 28.18416, -177.3879...
# Australia      MULTIPOLYGON (((142.27997 -10.26556, 142.18942...
# Antarctica     MULTIPOLYGON (((51.80305 -46.45667, 51.71055 -...
#
#                total_pageviews
# CONTINENT
# Asia                 612141949
# North America        782180032
# Europe               865439399
# Africa               793128292
# South America         56138972
# Oceania              181356930
# Australia            808044997
# Antarctica           573193996

# %%
gdf.index
# Out:
# Index(['Asia', 'North America', 'Europe', 'Africa', 'South America', 'Oceania',
#        'Australia', 'Antarctica'],
#       dtype='object', name='CONTINENT')

# %%
import plotly.express as px
pollution_HAT_gas_continent.head(20)
# Out:
#        continent  Gas Consumption - TWh  Exposure Mean
# 0           Asia          196940.903000      90.333107
# 1  North America          110553.857030       0.080380
# 2         Europe           75640.169110      23.141980
# 3         Africa           10624.825338       3.386640
# 4  South America           28967.576004      15.719850
# 5        Oceania            5063.449628       0.185050
# 6      Australia               0.000000       0.000000
# 7     Antarctica               0.000000       0.000000

# %%
px.choropleth_mapbox(
    pollution_HAT_gas_continent,
    geojson=gdf.geometry,
    locations=pollution_HAT_gas_continent.continent,
    color="Exposure Mean",
    mapbox_style="carto-positron",
    color_continuous_scale="Reds",
    opacity=0.5,
    zoom=1,
).update_layout(margin={"l": 0, "r": 0, "b": 0, "t": 0})
fig.write_html("geo2.html")

# %%
fig = px.choropleth_mapbox(
    pollution_HAT_gas_continent,
    geojson=gdf.geometry,
    locations=pollution_HAT_gas_continent.continent,
    color="Exposure Mean",
    mapbox_style="carto-positron",
    color_continuous_scale="Reds",
    opacity=0.5,
    zoom=1,
).update_layout(margin={"l": 0, "r": 0, "b": 0, "t": 0})
fig.write_html("file.html")
